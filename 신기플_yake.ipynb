# %%
pip install yake
# Out:
# Collecting yake
#   Downloading yake-0.4.8-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from yake) (0.9.0)
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.10/dist-packages (from yake) (8.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from yake) (1.23.5)
# Collecting segtok (from yake)
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from yake) (3.1)
# Collecting jellyfish (from yake)
#   Downloading jellyfish-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 40.5 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from segtok->yake) (2022.10.31)
# Installing collected packages: segtok, jellyfish, yake
# Successfully installed jellyfish-1.0.0 segtok-1.5.11 yake-0.4.8

# %%
# !pip install konlpy
from konlpy.tag import Kkma
from konlpy.tag import Okt

okt = Okt()
kkma = Kkma()
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 27.5 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.4.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 48.6 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %%
import yake
from time import time
from konlpy.tag import Okt

okt = Okt()

language = "ko"
max_ngram_size = 1
deduplication_threshold = 0.9
deduplication_algo = 'lev'
windowSize = 1
numOfKeywords = 3

all_elements = [
    "미하하하하하하하하하하하하하하하하하하하하하하하하하하하하핳ㅎㅎㅎㅎㅎㅎ",
    "나꿍꼬또댜기꿍꼬또",
    "그냥 자라..누구냐너",
    "어디 갔다 왐수꽈?",
    "요새 어떵 살미꽈? 좋수과?",
    "당연이 줄 수 있지, 문자 한번 다시 다오~^^",
    "우리가 현준이를 종잡을 수 있겠나",
    "고대 연구실에서 나올리가…",
    "다들 곧 퇴근하시겠군요",
    "재택과 백수 앞에 무력하네요",
    "짐 놓고 와도 도착하는ㅅ ㅣ간 아님?",
    "9시에 만난다고하먀ㅏㄴ 난장판 되어있을듯 하다",
    "오랜만이야~ 보고싶었어~ 나도 요새 취준해… 너도 잘 살지?",
    "난 교내 학회에서 프로젝트 하고 있는데 팀원을 때문에 너무 힘들다!!!!",
    "나도 요새 수업 듣는데 좀 힘들다ㅠㅠㅠㅠ 무려 21학점 들어야 해… 살려줘ㅠㅠ 죽고싶어ㅠㅠㅠㅠㅋㅋㅋ",
    "나 요새 마라탕 자주 먹는데 개마싰음. 나중에 시간 되면 같이 먹으러 ㄱ?",
    "엄마 나 용돈 떨어졌어 용돈 제바류ㅠㅠㅠㅠㅠ",
    "여기에 각자 5개씩 제안해주시면 감사드리겠습니다 ㅎㅎ",
    "내일까지 10분 내외로 간단하게 해당 주제에 대한 설명(주제 소개, 목표, 데이터셋, 플로우 등)을 준비해주시면 됩니다",
    "30분에맞춰서 도착할듯?",
    "그럼 일단 방먹에서봐?",
    "이것대로 인스턴스 설정하고 활성화 해야 해",
    "나 진짜 너무 배고파",
    "헐~ ㅁㅊ 그럼 어케 되는겨?",
    "오키 그럼 내일 5시에 빨잠에서 보는걸루?",
    "저는 아아로 부탁드립니다~",
    "잘자구 내일 보쟈잉!",
    "엥 ㅁㅊ 어떻게 그럴 수 있음???",
    "아 가보자고",
    "어케 해야 하는지 감이 오는 것 같음",
    "ㅇㅎ…..오비맥주도 저기 겅ㅅ구나……? 흥ㅁ로구먼"
]
start_time = time()

for text in all_elements:

    #품사 고려 안 하기로 함, 어절 단위로만 추출하자!
    # Tag words by parts of speech and filter only nouns, adjectives, and verbs
    #pos_tags = ["Noun", "Adjective", "Verb"]
    #filtered_words = [word for word, tag in okt.pos(text) if tag in pos_tags]

    #filtered_text = " ".join(filtered_words)

    custom_kw_extractor = yake.KeywordExtractor(lan=language,
                                                n=max_ngram_size,
                                                dedupLim=deduplication_threshold,
                                                dedupFunc=deduplication_algo,
                                                windowsSize=windowSize,
                                                top=numOfKeywords,
                                                features=None)
    keywords = custom_kw_extractor.extract_keywords(text)


    print(f"Keywords for text: '{text}'")
    for kw, score in keywords:  # lower the score, more relevant the keyword
        tag = None
        for word, tag_ in okt.pos(kw):  # Corrected the loop for unpacking word-tag pairs
            if kw == word:
                tag = tag_
                break
        print(f"{kw} (Score: {score:.4f})")
    print("\n")

end_time = time()
running_time = end_time - start_time

print("model running time: %s " % f"{running_time:12.9f}", end="")
# Out:
# Keywords for text: '미하하하하하하하하하하하하하하하하하하하하하하하하하하하하핳ㅎㅎㅎㅎㅎㅎ'
# 미하하하하하하하하하하하하하하하하하하하하하하하하하하하하핳ㅎㅎㅎㅎㅎㅎ (Score: 0.0449)
#
#
# Keywords for text: '나꿍꼬또댜기꿍꼬또'
# 나꿍꼬또댜기꿍꼬또 (Score: 0.0449)
#
#
# Keywords for text: '그냥 자라..누구냐너'
#
#
# Keywords for text: '어디 갔다 왐수꽈?'
# 왐수꽈 (Score: 0.1583)
#
#
# Keywords for text: '요새 어떵 살미꽈? 좋수과?'
# 좋수과 (Score: 0.1788)
# 살미꽈 (Score: 0.2005)
#
#
# Keywords for text: '당연이 줄 수 있지, 문자 한번 다시 다오~^^'
# 당연이 (Score: 0.1583)
#
#
# Keywords for text: '우리가 현준이를 종잡을 수 있겠나'
# 우리가 (Score: 0.1583)
# 있겠나 (Score: 0.1583)
# 현준이를 (Score: 0.2974)
#
#
# Keywords for text: '고대 연구실에서 나올리가…'
# 나올리가… (Score: 0.1583)
# 연구실에서 (Score: 0.2974)
#
#
# Keywords for text: '다들 곧 퇴근하시겠군요'
# 퇴근하시겠군요 (Score: 0.1583)
#
#
# Keywords for text: '재택과 백수 앞에 무력하네요'
# 재택과 (Score: 0.1583)
# 무력하네요 (Score: 0.1583)
#
#
# Keywords for text: '짐 놓고 와도 도착하는ㅅ ㅣ간 아님?'
# 도착하는ㅅ (Score: 0.2974)
#
#
# Keywords for text: '9시에 만난다고하먀ㅏㄴ 난장판 되어있을듯 하다'
# 만난다고하먀ㅏㄴ (Score: 0.2974)
# 난장판 (Score: 0.2974)
# 되어있을듯 (Score: 0.2974)
#
#
# Keywords for text: '오랜만이야~ 보고싶었어~ 나도 요새 취준해… 너도 잘 살지?'
# 오랜만이야~ (Score: 0.1583)
# 보고싶었어~ (Score: 0.2974)
# 취준해… (Score: 0.2974)
#
#
# Keywords for text: '난 교내 학회에서 프로젝트 하고 있는데 팀원을 때문에 너무 힘들다!!!!'
# 학회에서 (Score: 0.2974)
# 프로젝트 (Score: 0.2974)
# 있는데 (Score: 0.2974)
#
#
# Keywords for text: '나도 요새 수업 듣는데 좀 힘들다ㅠㅠㅠㅠ 무려 21학점 들어야 해… 살려줘ㅠㅠ 죽고싶어ㅠㅠㅠㅠㅋㅋㅋ'
# 죽고싶어ㅠㅠㅠㅠㅋㅋㅋ (Score: 0.1583)
# 듣는데 (Score: 0.2974)
# 힘들다ㅠㅠㅠㅠ (Score: 0.2974)
#
#
# Keywords for text: '나 요새 마라탕 자주 먹는데 개마싰음. 나중에 시간 되면 같이 먹으러 ㄱ?'
# 개마싰음 (Score: 0.2005)
# 마라탕 (Score: 0.3607)
# 먹는데 (Score: 0.3607)
#
#
# Keywords for text: '엄마 나 용돈 떨어졌어 용돈 제바류ㅠㅠㅠㅠㅠ'
# 제바류ㅠㅠㅠㅠㅠ (Score: 0.0957)
# 떨어졌어 (Score: 0.1583)
#
#
# Keywords for text: '여기에 각자 5개씩 제안해주시면 감사드리겠습니다 ㅎㅎ'
# 여기에 (Score: 0.1583)
# 제안해주시면 (Score: 0.2974)
# 감사드리겠습니다 (Score: 0.2974)
#
#
# Keywords for text: '내일까지 10분 내외로 간단하게 해당 주제에 대한 설명(주제 소개, 목표, 데이터셋, 플로우 등)을 준비해주시면 됩니다'
# 내일까지 (Score: 0.0449)
# 데이터셋 (Score: 0.0449)
# 플로우 (Score: 0.1583)
#
#
# Keywords for text: '30분에맞춰서 도착할듯?'
# 분에맞춰서 (Score: 0.1583)
# 도착할듯 (Score: 0.1583)
#
#
# Keywords for text: '그럼 일단 방먹에서봐?'
# 방먹에서봐 (Score: 0.1583)
#
#
# Keywords for text: '이것대로 인스턴스 설정하고 활성화 해야 해'
# 이것대로 (Score: 0.1583)
# 인스턴스 (Score: 0.2974)
# 설정하고 (Score: 0.2974)
#
#
# Keywords for text: '나 진짜 너무 배고파'
# 배고파 (Score: 0.1583)
#
#
# Keywords for text: '헐~ ㅁㅊ 그럼 어케 되는겨?'
# 되는겨 (Score: 0.1583)
#
#
# Keywords for text: '오키 그럼 내일 5시에 빨잠에서 보는걸루?'
# 보는걸루 (Score: 0.1583)
# 빨잠에서 (Score: 0.2974)
#
#
# Keywords for text: '저는 아아로 부탁드립니다~'
# 부탁드립니다~ (Score: 0.1583)
# 아아로 (Score: 0.2974)
#
#
# Keywords for text: '잘자구 내일 보쟈잉!'
# 잘자구 (Score: 0.1583)
# 보쟈잉 (Score: 0.1583)
#
#
# Keywords for text: '엥 ㅁㅊ 어떻게 그럴 수 있음???'
# 어떻게 (Score: 0.2974)
#
#
# Keywords for text: '아 가보자고'
# 가보자고 (Score: 0.1583)
#
#
# Keywords for text: '어케 해야 하는지 감이 오는 것 같음'
# 하는지 (Score: 0.2974)
#
#
# Keywords for text: 'ㅇㅎ…..오비맥주도 저기 겅ㅅ구나……? 흥ㅁ로구먼'
# 흥ㅁ로구먼 (Score: 0.1788)
# 겅ㅅ구나…… (Score: 0.2005)
#
#
# model running time:  0.133363485

# %%
#조사, 어미 제외한 버전

import yake
import re
from time import time
from konlpy.tag import Okt

okt = Okt()

language = "ko"
max_ngram_size = 1
deduplication_threshold = 0.9
deduplication_algo = 'lev'
windowSize = 1
numOfKeywords = 3

weight_mapping = {
    "Noun": 1.5,
    "Verb": 1.2,
    "Adjective": 1.2
}

punctuations = {",", ".", ":", ";", "?", "!", "#", "&", "(", ")", "-", "_", "=", "+", "[", "]", "{", "}", "|", "\\", "/", "<", ">", "~", "`", "@", "$", "%", "^", "*", "[SEP]", "[CLS]", "\""}

def tokenize_with_punctuations(text):
    for p in punctuations:
        text = text.replace(p, " ")
    return text.split()

all_elements = [
    "미하하하하하하하하하하하하하하하하하하하하하하하하하하하하핳ㅎㅎㅎㅎㅎㅎ",
    "나꿍꼬또댜기꿍꼬또",
    "그냥 자라..누구냐너",
    "어디 갔다 왐수꽈?",
    "요새 어떵 살미꽈? 좋수과?",
    "당연이 줄 수 있지, 문자 한번 다시 다오~^^",
    "우리가 현준이를 종잡을 수 있겠나",
    "고대 연구실에서 나올리가…",
    "다들 곧 퇴근하시겠군요",
    "재택과 백수 앞에 무력하네요",
    "짐 놓고 와도 도착하는ㅅ ㅣ간 아님?",
    "9시에 만난다고하먀ㅏㄴ 난장판 되어있을듯 하다",
    "오랜만이야~ 보고싶었어~ 나도 요새 취준해… 너도 잘 살지?",
    "난 교내 학회에서 프로젝트 하고 있는데 팀원을 때문에 너무 힘들다!!!!",
    "나도 요새 수업 듣는데 좀 힘들다ㅠㅠㅠㅠ 무려 21학점 들어야 해… 살려줘ㅠㅠ 죽고싶어ㅠㅠㅠㅠㅋㅋㅋ",
    "나 요새 마라탕 자주 먹는데 개마싰음. 나중에 시간 되면 같이 먹으러 ㄱ?",
    "엄마 나 용돈 떨어졌어 용돈 제바류ㅠㅠㅠㅠㅠ",
    "여기에 각자 5개씩 제안해주시면 감사드리겠습니다 ㅎㅎ",
    "내일까지 10분 내외로 간단하게 해당 주제에 대한 설명(주제 소개, 목표, 데이터셋, 플로우 등)을 준비해주시면 됩니다",
    "30분에맞춰서 도착할듯?",
    "그럼 일단 방먹에서봐?",
    "이것대로 인스턴스 설정하고 활성화 해야 해",
    "나 진짜 너무 배고파",
    "헐~ ㅁㅊ 그럼 어케 되는겨?",
    "오키 그럼 내일 5시에 빨잠에서 보는걸루?",
    "저는 아아로 부탁드립니다~",
    "잘자구 내일 보쟈잉!",
    "엥 ㅁㅊ 어떻게 그럴 수 있음???",
    "아 가보자고",
    "어케 해야 하는지 감이 오는 것 같음",
    "ㅇㅎ…..오비맥주도 저기 겅ㅅ구나……? 흥ㅁ로구먼"
]


start_time = time()

for text in all_elements:
    tokenized_words = tokenize_with_punctuations(text)

    #pos_tags = ["Noun", "Adjective", "Verb"]
    filtered_words = []

    # Use konlpy to filter out particles and endings
    for word, tag in okt.pos(" ".join(tokenized_words)):
        if tag not in ['Josa', 'Eomi']:
            filtered_words.append(word)

    filtered_text = " ".join(filtered_words)

    custom_kw_extractor = yake.KeywordExtractor(lan=language,
                                                n=max_ngram_size,
                                                dedupLim=deduplication_threshold,
                                                dedupFunc=deduplication_algo,
                                                windowsSize=windowSize,
                                                top=numOfKeywords,
                                                features=None)
    keywords = custom_kw_extractor.extract_keywords(filtered_text)


    print(f"Keywords for text: '{text}'")
    for kw, score in keywords:
        tag = None
        for word, tag_ in okt.pos(kw):
            if kw == word:
                tag = tag_
                break
        print(f"{kw} (Score: {score:.4f})")
    print("\n")

end_time = time()
running_time = end_time - start_time

print("model running time: %s " % f"{running_time:12.9f}", end="")
# Out:
# Keywords for text: '미하하하하하하하하하하하하하하하하하하하하하하하하하하하하핳ㅎㅎㅎㅎㅎㅎ'
# ㅎㅎㅎㅎㅎㅎ (Score: 0.0517)
#
#
# Keywords for text: '나꿍꼬또댜기꿍꼬또'
# 꼬또댜기꿍꼬 (Score: 0.2974)
#
#
# Keywords for text: '그냥 자라..누구냐너'
#
#
# Keywords for text: '어디 갔다 왐수꽈?'
# 왐수꽈 (Score: 0.1583)
#
#
# Keywords for text: '요새 어떵 살미꽈? 좋수과?'
# 좋수과 (Score: 0.1583)
# 살미꽈 (Score: 0.2974)
#
#
# Keywords for text: '당연이 줄 수 있지, 문자 한번 다시 다오~^^'
#
#
# Keywords for text: '우리가 현준이를 종잡을 수 있겠나'
# 있겠나 (Score: 0.1583)
#
#
# Keywords for text: '고대 연구실에서 나올리가…'
# 연구실 (Score: 0.2974)
#
#
# Keywords for text: '다들 곧 퇴근하시겠군요'
# 하시겠군요 (Score: 0.1583)
#
#
# Keywords for text: '재택과 백수 앞에 무력하네요'
# 무력하네요 (Score: 0.1583)
#
#
# Keywords for text: '짐 놓고 와도 도착하는ㅅ ㅣ간 아님?'
#
#
# Keywords for text: '9시에 만난다고하먀ㅏㄴ 난장판 되어있을듯 하다'
# 만난다고하 (Score: 0.2974)
# 난장판 (Score: 0.2974)
# 되어있을듯 (Score: 0.2974)
#
#
# Keywords for text: '오랜만이야~ 보고싶었어~ 나도 요새 취준해… 너도 잘 살지?'
# 취준해 (Score: 0.1583)
# 보고싶었어 (Score: 0.2974)
#
#
# Keywords for text: '난 교내 학회에서 프로젝트 하고 있는데 팀원을 때문에 너무 힘들다!!!!'
# 힘들다 (Score: 0.1583)
# 프로젝트 (Score: 0.2974)
# 있는데 (Score: 0.2974)
#
#
# Keywords for text: '나도 요새 수업 듣는데 좀 힘들다ㅠㅠㅠㅠ 무려 21학점 들어야 해… 살려줘ㅠㅠ 죽고싶어ㅠㅠㅠㅠㅋㅋㅋ'
# 살려줘 (Score: 0.1583)
# ㅠㅠㅠㅠㅋㅋㅋ (Score: 0.1583)
# 듣는데 (Score: 0.2974)
#
#
# Keywords for text: '나 요새 마라탕 자주 먹는데 개마싰음. 나중에 시간 되면 같이 먹으러 ㄱ?'
# 먹는데 (Score: 0.2974)
# 개마싰음 (Score: 0.2974)
# 먹으러 (Score: 0.2974)
#
#
# Keywords for text: '엄마 나 용돈 떨어졌어 용돈 제바류ㅠㅠㅠㅠㅠ'
# ㅠㅠㅠㅠㅠ (Score: 0.0957)
# 떨어졌어 (Score: 0.1583)
#
#
# Keywords for text: '여기에 각자 5개씩 제안해주시면 감사드리겠습니다 ㅎㅎ'
# 해주시면 (Score: 0.2974)
# 드리겠습니다 (Score: 0.2974)
#
#
# Keywords for text: '내일까지 10분 내외로 간단하게 해당 주제에 대한 설명(주제 소개, 목표, 데이터셋, 플로우 등)을 준비해주시면 됩니다'
# 됩니다 (Score: 0.0957)
# 간단하게 (Score: 0.1583)
# 데이터 (Score: 0.1583)
#
#
# Keywords for text: '30분에맞춰서 도착할듯?'
# 에맞춰서 (Score: 0.2974)
#
#
# Keywords for text: '그럼 일단 방먹에서봐?'
# 먹에서 (Score: 0.2974)
#
#
# Keywords for text: '이것대로 인스턴스 설정하고 활성화 해야 해'
# 인스턴스 (Score: 0.2974)
# 활성화 (Score: 0.2974)
#
#
# Keywords for text: '나 진짜 너무 배고파'
# 배고파 (Score: 0.1583)
#
#
# Keywords for text: '헐~ ㅁㅊ 그럼 어케 되는겨?'
#
#
# Keywords for text: '오키 그럼 내일 5시에 빨잠에서 보는걸루?'
# 보는걸 (Score: 0.2974)
#
#
# Keywords for text: '저는 아아로 부탁드립니다~'
# 부탁드립니다 (Score: 0.1583)
#
#
# Keywords for text: '잘자구 내일 보쟈잉!'
# 보쟈잉 (Score: 0.1583)
#
#
# Keywords for text: '엥 ㅁㅊ 어떻게 그럴 수 있음???'
# 어떻게 (Score: 0.2974)
#
#
# Keywords for text: '아 가보자고'
# 가보자고 (Score: 0.1583)
#
#
# Keywords for text: '어케 해야 하는지 감이 오는 것 같음'
# 하는지 (Score: 0.2974)
#
#
# Keywords for text: 'ㅇㅎ…..오비맥주도 저기 겅ㅅ구나……? 흥ㅁ로구먼'
# 오비맥주 (Score: 0.1583)
#
#
# model running time:  0.130318165
